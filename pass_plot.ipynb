# %% [markdown]
# ### Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from mplsoccer import Pitch, Sbopen

# %% [markdown]
# ### Open the data and create a data frame

# %%
parser = Sbopen()
df, related, freeze, tactics = parser.event(69301)

# %%
df.shape
# Out:
# (3291, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3291 entries, 0 to 3290
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3291 non-null   object
#  1   index                           3291 non-null   int64
#  2   period                          3291 non-null   int64
#  3   timestamp                       3291 non-null   object
#  4   minute                          3291 non-null   int64
#  5   second                          3291 non-null   int64
#  6   possession                      3291 non-null   int64
#  7   duration                        2457 non-null   float64
#  8   match_id                        3291 non-null   int64
#  9   type_id                         3291 non-null   int64
#  10  type_name                       3291 non-null   object
#  11  possession_team_id              3291 non-null   int64
# ...

# %%
df.head()
# Out:
#                                      id  index  period        timestamp  \
# 0  e8643796-c76d-44f5-a03d-fa742e051942      1       1         00:00:00
# 1  937f83f8-674d-4c58-81d5-e2101a9f2e60      2       1         00:00:00
# 2  87ba272a-3af0-4fc7-872f-65e8f79fb753      3       1         00:00:00
# 3  85d30bef-8b77-405e-bc64-c63ed4d7a6d7      4       1         00:00:00
# 4  760528a6-2de2-427f-9795-b2b19819ef1f      5       1  00:00:00.140000
#
#    minute  second  possession  duration  match_id  type_id  ...  \
# 0       0       0           1   0.00000     69301       35  ...
# 1       0       0           1   0.00000     69301       35  ...
# 2       0       0           1   0.00000     69301       18  ...
# 3       0       0           1   0.00000     69301       18  ...
# 4       0       0           2   0.16873     69301       30  ...
#
#   block_deflection  pass_cut_back bad_behaviour_card_id  \
# 0              NaN            NaN                   NaN
# ...

# %% [markdown]
# ### Filter the data frame so only passes are left (and remove throw-ins)

# %%
passes = df.loc[df['type_name'] == 'Pass'].loc[df['sub_type_name'] != 'Throw-in'].set_index('id')

# %%
passes.head()
# Out:
#                                       index  period        timestamp  minute  \
# id
# 760528a6-2de2-427f-9795-b2b19819ef1f      5       1  00:00:00.140000       0
# ecec23b8-f03d-4bee-80df-9fabec558187      9       1  00:00:05.143000       0
# bdedb943-ddac-42ab-bc8b-756faa49d9e6     12       1  00:00:07.844000       0
# 456a1ae6-1fe8-4ffc-952b-152a7f89e1d2     15       1  00:00:10.586000       0
# a8d0155f-260c-4470-b842-b474ea58ffa7     19       1  00:00:11.326000       0
#
#                                       second  possession  duration  match_id  \
# id
# 760528a6-2de2-427f-9795-b2b19819ef1f       0           2  0.168730     69301
# ecec23b8-f03d-4bee-80df-9fabec558187       5           2  1.173625     69301
# bdedb943-ddac-42ab-bc8b-756faa49d9e6       7           2  1.019100     69301
# 456a1ae6-1fe8-4ffc-952b-152a7f89e1d2      10           2  0.700000     69301
# a8d0155f-260c-4470-b842-b474ea58ffa7      11           2  4.150000     69301
#
# ...

# %% [markdown]
# ### Iterative solution pass match

# %% [markdown]
# 1. Draw the pitch
# 2. Next, iterate through the passes. Check if a pass was made by Lucy Bronze.
# 3. If so, take the starting coordinates of a pass and plot a circle.
# 4. Then, subtract the coordinates beginning of the pass from the end of passes in order to draw pass arrows.

# %%
# Draw the pitch!
pitch = Pitch(line_color='black')
fig, ax = pitch.draw(figsize=(10,7))
